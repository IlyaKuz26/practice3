# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import pickle

# %% [markdown]
# # Загрузка данных

# %%
data_path = r"../data/bankruptcy_data.csv"
data = pd.read_csv(data_path, index_col=0)

# %%
data.head(10)

# %%
data.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2846300 entries, 0 to 3104783
# Data columns (total 40 columns):
#  #   Column                                             Non-Null Count    Dtype
# ---  ------                                             --------------    -----
#  0   Наименование                                       2846300 non-null  object
#  1   Регистрационный номер                              2846300 non-null  float64
#  2   Код налогоплательщика                              2846300 non-null  float64
#  3   Вид деятельности/отрасль                           2846300 non-null  object
#  4   Код основного вида деятельности                    2846300 non-null  object
#  5   Организационно-правовая форма                      2846300 non-null  object
#  6   Форма собственности                                2846300 non-null  object
#  7   Размер компании                                    2846258 non-null  object
#  8   Важная информация                                  337634 non-null   object
#  9   Год                                                2846300 non-null  int64
#  10  Основные средства , RUB                            1196099 non-null  float64
#  11  Внеоборотные активы, RUB                           1301418 non-null  float64
#  12  Запасы, RUB                                        1881476 non-null  float64
#  13  Дебиторская задолженность, RUB                     2460721 non-null  float64
#  14  Краткосрочные финансовые вложения, RUB             242635 non-null   float64
#  15  Денежные средства и денежные эквиваленты, RUB      2530127 non-null  float64
#  16  Оборотные активы, RUB                              2715856 non-null  float64
#  17  Активы  всего, RUB                                 2727109 non-null  float64
#  18  Нераспределенная прибыль (непокрытый убыток), RUB  1116254 non-null  float64
#  19  Капитал и резервы, RUB                             2714135 non-null  float64
#  20  Заёмные средства (долгосрочные), RUB               643865 non-null   float64
#  21  Долгосрочные обязательства, RUB                    798852 non-null   float64
#  22  Заёмные средства (краткосрочные), RUB              934555 non-null   float64
#  23  Кредиторская задолженность, RUB                    2525816 non-null  float64
#  24  Доходы будущих периодов , RUB                      34855 non-null    float64
#  25  Краткосрочные обязательства, RUB                   2574163 non-null  float64
#  26  Выручка, RUB                                       2667643 non-null  float64
#  27  Себестоимость продаж, RUB                          2498030 non-null  float64
#  28  Валовая прибыль (убыток), RUB                      1141811 non-null  float64
#  29  Коммерческие расходы, RUB                          433119 non-null   float64
#  30  Управленческие расходы, RUB                        567236 non-null   float64
#  31  Прибыль (убыток) от продажи, RUB                   2665085 non-null  float64
#  32  Проценты к получению, RUB                          175665 non-null   float64
#  33  Проценты к уплате, RUB                             335381 non-null   float64
#  34  Прочие доходы, RUB                                 1215384 non-null  float64
#  35  Прочие расходы, RUB                                2357413 non-null  float64
#  36  Прибыль (убыток) до налогообложения , RUB          2615447 non-null  float64
#  37  Текущий налог на прибыль, RUB                      1888376 non-null  float64
#  38  Чистая прибыль (убыток), RUB                       2644839 non-null  float64
#  39  Банкротство                                        2846300 non-null  int64
# dtypes: float64(31), int64(2), object(7)
# memory usage: 890.3+ MB

# %% [markdown]
# # Обработка данных

# %%
data[data["Банкротство"] == 0]
# Out:
#                         Наименование  Регистрационный номер  \
# 0                       ИМПРЕЗА, ООО           1.087746e+12
# 1                  ФУД ТРЕЙД ДВ, ООО           1.202500e+12
# 2           ПЛАНЕТА ИНСТРУМЕНТА, ООО           1.195275e+12
# 3           ЖИЛКОМФОРТСЕРВИС, ООО УК           1.152310e+12
# 4                      ВС-ГРУПП, ООО           1.146952e+12
# ...                              ...                    ...
# 320976                    СТАРТ, ООО           5.167746e+12
# 320977               СИБ СЕРВИС, ООО           1.196658e+12
# 320978  ВОРОНЕЖСКАЯ АГРОТЕХНИКА, ООО           1.113668e+12
# 320979                РУСЬСТРОЙ, ООО           1.063525e+12
# 320980            ПРОФИТ ВОСТОК, ООО           1.082722e+12
#
#         Код налогоплательщика  \
# 0                7.725631e+09
# 1                2.543149e+09
# 2                5.261122e+09
# 3                2.310187e+09
# 4                6.950182e+09
# ...                       ...
# 320976           7.702407e+09
# 320977           6.686113e+09
# 320978           3.663088e+09
# 320979           3.525167e+09
# 320980           2.722071e+09
#
#                                  Вид деятельности/отрасль  \
# 0            Торговля оптовая фармацевтической продукцией
# 1       Торговля оптовая прочими пищевыми продуктами, ...
# 2                   Торговля оптовая неспециализированная
# 3       Аренда и управление собственным или арендованн...
# 4       Торговля розничная безалкогольными напитками в...
# ...                                                   ...
# 320976  Торговля розничная различной домашней утварью,...
# 320977       Обработка металлических изделий механическая
# 320978  Производство машин и оборудования для сельског...
# 320979                     Работы строительные отделочные
# 320980  Управление недвижимым имуществом за вознагражд...
#
#        Код основного вида деятельности  \
# 0                                46.46
# 1                                46.38
# 2                                46.90
# 3                                68.20
# 4                              47.25.2
# ...                                ...
# 320976                         47.59.2
# 320977                           25.62
# 320978                            28.3
# 320979                            43.3
# 320980                           68.32
#
#                    Организационно-правовая форма    Форма собственности  \
# 0       Общества с ограниченной ответственностью  Частная собственность
# 1       Общества с ограниченной ответственностью  Частная собственность
# 2       Общества с ограниченной ответственностью  Частная собственность
# 3       Общества с ограниченной ответственностью  Частная собственность
# 4       Общества с ограниченной ответственностью  Частная собственность
# ...                                          ...                    ...
# 320976  Общества с ограниченной ответственностью  Частная собственность
# 320977  Общества с ограниченной ответственностью  Частная собственность
# 320978  Общества с ограниченной ответственностью  Частная собственность
# 320979  Общества с ограниченной ответственностью  Частная собственность
# 320980  Общества с ограниченной ответственностью  Частная собственность
#
#           Размер компании Важная информация   Год  ...  \
# 0        Микропредприятия               NaN  2020  ...
# 1        Микропредприятия               NaN  2019  ...
# 2        Микропредприятия               NaN  2020  ...
# 3        Микропредприятия               NaN  2020  ...
# 4        Микропредприятия               NaN  2019  ...
# ...                   ...               ...   ...  ...
# 320976   Микропредприятия               NaN  2019  ...
# 320977   Микропредприятия               NaN  2019  ...
# 320978  Малые предприятия               NaN  2019  ...
# 320979   Микропредприятия               NaN  2019  ...
# 320980   Микропредприятия               NaN  2020  ...
#
#         Управленческие расходы, RUB  Прибыль (убыток) от продажи, RUB  \
# 0                               NaN                        39312000.0
# 1                               NaN                               NaN
# 2                               NaN                          106000.0
# 3                         2007000.0                       -13312000.0
# 4                               NaN                          455000.0
# ...                             ...                               ...
# 320976                          NaN                        17432000.0
# 320977                     392000.0                           58000.0
# 320978                          NaN                         1132000.0
# 320979                          NaN                           22000.0
# 320980                          NaN                           50000.0
#
#         Проценты к получению, RUB  Проценты к уплате, RUB  Прочие доходы, RUB  \
# 0                             NaN                     NaN             52000.0
# 1                             NaN                     NaN                 NaN
# 2                             NaN                     NaN                 NaN
# 3                             NaN                     NaN            340000.0
# 4                             NaN                     NaN            155000.0
# ...                           ...                     ...                 ...
# 320976                        NaN                     NaN              3000.0
# 320977                        NaN                     NaN                 NaN
# 320978                        NaN                     NaN                 NaN
# 320979                        NaN                     NaN                 NaN
# 320980                        NaN                     NaN                 NaN
#
#         Прочие расходы, RUB  Прибыль (убыток) до налогообложения , RUB  \
# 0                 5733000.0                                 33631000.0
# 1                       NaN                                        NaN
# 2                   87000.0                                    19000.0
# 3                  139000.0                                -13111000.0
# 4                  247000.0                                   363000.0
# ...                     ...                                        ...
# 320976             104000.0                                 17331000.0
# 320977               7000.0                                    51000.0
# 320978                  NaN                                  1132000.0
# 320979              16000.0                                     6000.0
# 320980              31000.0                                    19000.0
#
#         Текущий налог на прибыль, RUB  Чистая прибыль (убыток), RUB  \
# 0                           4833000.0                    28798000.0
# 1                                 NaN                           NaN
# 2                              4000.0                       15000.0
# 3                           -266000.0                   -13377000.0
# 4                            -78000.0                      285000.0
# ...                               ...                           ...
# 320976                      2309000.0                    15022000.0
# 320977                            NaN                       41000.0
# 320978                            NaN                      906000.0
# 320979                            NaN                        6000.0
# 320980                        14000.0                        5000.0
#
#         Банкротство
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 320976            0
# 320977            0
# 320978            0
# 320979            0
# 320980            0
#
# [300001 rows x 40 columns]

# %%
data_zero.head(5)
# Out:
#        Наименование  Регистрационный номер  Код налогоплательщика  \
# 0   ОЛЕУМ-АВТО, ООО           1.185027e+12           5.027265e+09
# 1      ОПТТОРГ, ООО           1.192375e+12           2.372026e+09
# 2  ПОСУДА ПРОФ, ООО           1.203800e+12           3.811469e+09
# 3          РИК, ООО           1.192225e+12           2.221247e+09
# 4     ЛОГОС, ООО КЦ           1.027404e+12           7.452032e+09
#
#                             Вид деятельности/отрасль  \
# 0  Торговля оптовая автомобильными деталями, узла...
# 1  Торговля оптовая лесоматериалами, строительным...
# 2  Торговля оптовая изделиями из керамики и стекл...
# 3                    Деятельность рекламных агентств
# 4                       Деятельность в области права
#
#   Код основного вида деятельности             Организационно-правовая форма  \
# 0                         45.31.1  Общества с ограниченной ответственностью
# 1                           46.73  Общества с ограниченной ответственностью
# 2                           46.44  Общества с ограниченной ответственностью
# 3                           73.11  Общества с ограниченной ответственностью
# 4                           69.10  Общества с ограниченной ответственностью
#
#      Форма собственности   Размер компании Важная информация   Год  ...  \
# 0  Частная собственность  Микропредприятия               NaN  2020  ...
# 1  Частная собственность  Микропредприятия               NaN  2020  ...
# 2  Частная собственность  Микропредприятия               NaN  2019  ...
# 3  Частная собственность  Микропредприятия               NaN  2020  ...
# 4  Частная собственность  Микропредприятия               NaN  2020  ...
#
#    Управленческие расходы, RUB  Прибыль (убыток) от продажи, RUB  \
# 0                          NaN                         1654000.0
# 1                     570000.0                          442000.0
# 2                          NaN                               NaN
# 3                          NaN                            5000.0
# 4                          NaN                          408000.0
#
#    Проценты к получению, RUB  Проценты к уплате, RUB  Прочие доходы, RUB  \
# 0                        NaN                     NaN                 NaN
# 1                        NaN                     NaN                 NaN
# 2                        NaN                     NaN                 NaN
# 3                        NaN                     NaN                 NaN
# 4                        NaN                     NaN                 NaN
#
#    Прочие расходы, RUB  Прибыль (убыток) до налогообложения , RUB  \
# 0              51000.0                                  1603000.0
# 1             321000.0                                   121000.0
# 2                  NaN                                        NaN
# 3                  NaN                                     5000.0
# 4                  NaN                                   408000.0
#
#    Текущий налог на прибыль, RUB  Чистая прибыль (убыток), RUB  Банкротство
# 0                       322000.0                     1281000.0            0
# 1                       -24000.0                       97000.0            0
# 2                            NaN                           NaN            0
# 3                         4000.0                        1000.0            0
# 4                       -28000.0                      380000.0            0
#
# [5 rows x 40 columns]

# %%
def preprocess_data(data):

    data.reset_index(inplace = True, drop=True)
    
    # Удаление ненужных столбцов
    data.drop(["Наименование", "Регистрационный номер", "Код налогоплательщика", "Код основного вида деятельности"], axis = 1, inplace = True)
    
    # Перевод категориальных признаков в числовые
    data["Вид деятельности/отрасль"] = data["Вид деятельности/отрасль"].astype("category").cat.codes
    data["Организационно-правовая форма"] = data["Организационно-правовая форма"].astype("category").cat.codes
    data["Форма собственности"] = data["Форма собственности"].astype("category").cat.codes
    data["Размер компании"] = data["Размер компании"].astype("category").cat.codes

    # Заполнение пропусков
    data.fillna(0, inplace = True)
    # Преобразование признака Важная информация
    data["Важная информация"].where(data["Важная информация"] == 0, other = 1, inplace = True)
    data["Важная информация"] = data["Важная информация"].astype("int8")
    
    #Уменьшение числа строк
    data_nonzero = data.loc[(data["Бакротство"] != 0), [300000,:]]
    data_zero = data.loc[(data["Бакротство"] == 0), [:300000,:]]
    
    #Уменьшение числа строк
    data_nonzero = data.loc[(data["Банкротство"] != 0)]
    data_zero = data.loc[(data["Банкротство"] == 0)]
    data_zero = data_zero.sample(frac=1).reset_index(drop=True)
    data_zero = data_zero.loc[0:300000, :]
    data = pd.concat([data_nonzero, data_zero], axis=0).sample(frac=1).reset_index(drop=True)
    
    # Отделение целевого признака
    X = data.drop("Банкротство", axis = 1)
    y = data["Банкротство"]
    
    return X, y

# %%
X, y = preprocess_data(data)

# %%
def split_data(X, y, train_size):

    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = train_size)

    scaler = StandardScaler()

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_data(X, y, 0.7)

# %% [markdown]
# # Обучение модели

# %%
model = LogisticRegression(penalty = "l2", solver="sag", multi_class = "ovr", 
                            n_jobs = 3, verbose = 1).fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# max_iter reached after 277 seconds
# C:\Users\ilyap\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# max_iter reached after 280 secondsmax_iter reached after 280 seconds
# C:\Users\ilyap\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# max_iter reached after 216 seconds
# [Parallel(n_jobs=3)]: Done   4 out of   4 | elapsed:  8.2min remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   4 out of   4 | elapsed:  8.2min finished

# %%
y_train_result = model.predict(X_train)

print(y_train_result)
print(y_train_result.shape)
# Out:
# [0 0 0 ... 0 0 0]
# (1992409,)

# %% [markdown]
# # Оценка модели

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, multilabel_confusion_matrix

# %%
y_train_result = model.predict(X_train)
y_test_result = model.predict(X_test)

# %%
print(f"Train precision: {precision_score(y_true = y_train, y_pred = y_train_result, average = 'weighted')}")
print(f"Train recall: {recall_score(y_true = y_train, y_pred = y_train_result, average = 'weighted')}")
print(f"Train F1: {f1_score(y_true = y_train, y_pred = y_train_result, average = 'weighted')}\n")

print(f"Test precision: {precision_score(y_true = y_test, y_pred = y_test_result, average = 'weighted')}")
print(f"Test recall: {recall_score(y_true = y_test, y_pred = y_test_result, average = 'weighted')}")
print(f"Test F1: {f1_score(y_true = y_test, y_pred = y_test_result, average = 'weighted')}")
# Out:
# C:\Users\ilyap\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Train precision: 0.9886959005498192
# Train recall: 0.9926455863228886
# Train F1: 0.9890595825727716
#
# Test precision: 0.9878702904559787
# Test recall: 0.9925892180617901
# Test F1: 0.9889854861381909

# %%
# conf_matrix = multilabel_confusion_matrix(y_test, y_test_result, labels = [0, 1, 2, 3])
# sn.heatmap(conf_matrix, annot=True, annot_kws={"size": 16})

# %%
nonzero_data = np.where(y_test != 0)
nonzero_data_num = np.array(nonzero).reshape(-1).shape[0]
print(f"{nonzero_data_num} ненулевых целевых значений в тестовом датасете")

nonzero_result = np.where(y_test_result != 0)
nonzero_result_num = np.array(nonzero_result).reshape(-1).shape[0]
print(f"{nonzero_result_num} предсказанных ненулевых целевых значений")
print(f"Доля предсказанных ненулевых целевых значений {nonzero_result_num/nonzero_data_num:.3f}")
# Out:
# 14666 ненулевых целевых значений в тестовом датасете
# 80 предсказанных ненулевых целевых значений
# Доля предсказанных ненулевых целевых значений 0.005

# %%
def plot_weights(weights,names,model_type):
    

    feature_weights = np.array(weights)
    feature_names = np.array(names)
    

    data={'feature_names':feature_names,'feature_weights':feature_weights}
    fi_df = pd.DataFrame(data)
    

    fi_df.sort_values(by=['feature_weights'], ascending=False,inplace=True)
    

    plt.figure(figsize=(20,40))

    sn.barplot(x=fi_df['feature_weights'], y=fi_df['feature_names'])

    plt.title(model_type + ' Weights')
    plt.xlabel('Weights')
    plt.ylabel('Feature names')

# %%
plot_weights(model.coef_[0], data.drop("Банкротство", axis = 1).columns, "LogisticRegression")

# %% [markdown]
# # Сохранение модели

# %%
with open('../model/best_model.pkl','wb') as f:
    pickle.dump(model, f)
